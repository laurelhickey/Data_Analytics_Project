# %% [markdown]
# # Wine Reviews

# %%
import pandas as pd
import numpy as np
import json
import folium
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv("winemag-data-130k-v2.csv", index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  object
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 13.9+ MB

# %%
df = df.dropna(subset=["country", "description", "points", "price", "variety", "province"]).reset_index().drop("index", axis=1)
df = df.drop_duplicates("description")
df["country"] = np.where(df["country"] == "US", "United States of America", df["country"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111511 entries, 0 to 120914
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                111511 non-null  object
#  1   description            111511 non-null  object
#  2   designation            79472 non-null   object
#  3   points                 111511 non-null  int64
#  4   price                  111511 non-null  float64
#  5   province               111511 non-null  object
#  6   region_1               93556 non-null   object
#  7   region_2               46559 non-null   object
#  8   taster_name            88244 non-null   object
#  9   taster_twitter_handle  83761 non-null   object
#  10  title                  111511 non-null  object
#  11  variety                111511 non-null  object
#  12  winery                 111511 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 11.9+ MB

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 16
BIGGER_SIZE = 12
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)  
sns.distplot(df['points'], kde=False, fit=stats.norm).set(title='Points distribution (%)')
# Out:
# /Users/afnan/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Points distribution (%)')]

# %%
df[df['price'] < 100]['price'].plot.hist().set(title='Price frequency distribution')
# Out:
# [Text(0.5, 1.0, 'Price frequency distribution')]

# %%
#sns.kdeplot(data=df[df['price'] < 100].loc[:, ['price', 'points']], x='price', y='points')

# %%
sns.jointplot(y='price', x='points', data=df[df['price'] < 100], kind='hex', gridsize=20)

# %%
plt.figure(figsize=(10,10))
sns.lmplot(y = 'price', x='points', data=df[df['price'] < 100])

# %%
df_top_5 = df[df["variety"].isin(df["variety"].value_counts().head(5).index)]

sns.boxplot(data=df_top_5, y="variety", x="points")
# Out:
# <AxesSubplot:xlabel='points', ylabel='variety'>

# %%
df_top_5[["points", "variety"]].value_counts().unstack().plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='points'>

# %%
df["description_length"] = df["description"].apply(len)
plt.figure(figsize=(10,5))
sns.boxplot(data=df, x="points", y="description_length")
# Out:
# <AxesSubplot:xlabel='points', ylabel='description_length'>

# %% [markdown]
# ## Map

# %%
# JSON cleaning
with open("countries.json") as f:
    raw_countries_json = json.load(f)
countries_json = {"type": "FeatureCollection", "features" : []}
for feature in raw_countries_json["features"]:
    if feature["properties"]["name"] in df["country"].unique():
        countries_json["features"].append(feature)

# %%
m = folium.Map(location=[0, 0], zoom_start=2)

folium.Choropleth(
    geo_data=countries_json,
    data=df,
    columns=["country", "price"],
    key_on="feature.properties.name",
    fill_color="YlOrRd",
    fill_opacity=0.7,
    line_opacity=0.2,
    name="Price",
).add_to(m)

folium.Choropleth(
    geo_data=countries_json,
    data=df,
    columns=["country", "points"],
    key_on="feature.properties.name",
    fill_color="YlGnBu",
    fill_opacity=0.7,
    line_opacity=0.2,
    name="Points",
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13320b453a686fda3b0edabbd2aaf733 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13320b453a686fda3b0edabbd2aaf733&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_13320b453a686fda3b0edabbd2aaf733 = L.map(
#                 &quot;map_13320b453a686fda3b0edabbd2aaf733&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b38bb66f1a0c76d9fbf09367e82dbfa4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_13320b453a686fda3b0edabbd2aaf733);
#
#
#             var choropleth_715676ceae8d36129d7d3e860790ed48 = L.featureGroup(
#                 {}
#             ).addTo(map_13320b453a686fda3b0edabbd2aaf733);
#
#
#         function geo_json_8a5fdf3cff332582145d57f6aef2c5e0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;ARG&quot;: case &quot;CAN&quot;: case &quot;LBN&quot;: case &quot;PRT&quot;: case &quot;SVN&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AUS&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AUT&quot;: case &quot;USA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;BGR&quot;: case &quot;CHE&quot;: case &quot;DEU&quot;: case &quot;FRA&quot;: case &quot;HUN&quot;: case &quot;ISR&quot;: case &quot;LUX&quot;: case &quot;TUR&quot;: case &quot;URY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;BRA&quot;: case &quot;GRC&quot;: case &quot;HRV&quot;: case &quot;ITA&quot;: case &quot;NZL&quot;: case &quot;ZAF&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_8a5fdf3cff332582145d57f6aef2c5e0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8a5fdf3cff332582145d57f6aef2c5e0 = L.geoJson(null, {
#                 onEachFeature: geo_json_8a5fdf3cff332582145d57f6aef2c5e0_onEachFeature,
#
#                 style: geo_json_8a5fdf3cff332582145d57f6aef2c5e0_styler,
#         });
#
#         function geo_json_8a5fdf3cff332582145d57f6aef2c5e0_add (data) {
#             geo_json_8a5fdf3cff332582145d57f6aef2c5e0
#                 .addData(data)
#                 .addTo(choropleth_715676ceae8d36129d7d3e860790ed48);
#         }
#             geo_json_8a5fdf3cff332582145d57f6aef2c5e0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-65.5, -55.2], [-66.45, -55.25], [-66.95992, -54.89681], [-67.56244, -54.87001], [-68.63335, -54.8695], [-68.63401, -52.63637], [-68.25, -53.1], [-67.75, -53.85], [-66.45, -54.45], [-65.05, -54.7], [-65.5, -55.2]]], [[[-64.964892, -22.075862], [-64.377021, -22.798091], [-63.986838, -21.993644], [-62.846468, -22.034985], [-62.685057, -22.249029], [-60.846565, -23.880713], [-60.028966, -24.032796], [-58.807128, -24.771459], [-57.777217, -25.16234], [-57.63366, -25.603657], [-58.618174, -27.123719], [-57.60976, -27.395899], [-56.486702, -27.548499], [-55.695846, -27.387837], [-54.788795, -26.621786], [-54.625291, -25.739255], [-54.13005, -25.547639], [-53.628349, -26.124865], [-53.648735, -26.923473], [-54.490725, -27.474757], [-55.162286, -27.881915], [-56.2909, -28.852761], [-57.625133, -30.216295], [-57.874937, -31.016556], [-58.14244, -32.044504], [-58.132648, -33.040567], [-58.349611, -33.263189], [-58.427074, -33.909454], [-58.495442, -34.43149], [-57.22583, -35.288027], [-57.362359, -35.97739], [-56.737487, -36.413126], [-56.788285, -36.901572], [-57.749157, -38.183871], [-59.231857, -38.72022], [-61.237445, -38.928425], [-62.335957, -38.827707], [-62.125763, -39.424105], [-62.330531, -40.172586], [-62.145994, -40.676897], [-62.745803, -41.028761], [-63.770495, -41.166

# %% [markdown]
# # Sentiment Analysis

# %%
from nltk import sent_tokenize, word_tokenize 
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
df['compound'] = [analyzer.polarity_scores(x)['compound'] for x in df['description']]
df['neg'] = [analyzer.polarity_scores(x)['neg'] for x in df['description']]
df['neu'] = [analyzer.polarity_scores(x)['neu'] for x in df['description']]
df['pos'] = [analyzer.polarity_scores(x)['pos'] for x in df['description']]

# %%
corr = df.corr()
plt.figure(figsize=(6,6))
plt.title('Correlation')
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)
# Out:
# <AxesSubplot:title={'center':'Correlation'}>

# %%
df
# Out:
#                          country  \
# 0                       Portugal
# 1       United States of America
# 2       United States of America
# 3       United States of America
# 4                          Spain
# ...                          ...
# 120910                   Germany
# 120911  United States of America
# 120912                    France
# 120913                    France
# 120914                    France
#
#                                               description  \
# 0       This is ripe and fruity, a wine that is smooth...
# 1       Tart and snappy, the flavors of lime flesh and...
# 2       Pineapple rind, lemon pith and orange blossom ...
# 3       Much like the regular bottling from 2012, this...
# 4       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 120910  Notes of honeysuckle and cantaloupe sweeten th...
# 120911  Citation is given as much as a decade of bottl...
# 120912  Well-drained gravel soil gives this wine its c...
# 120913  A dry style of Pinot Gris, this is crisp with ...
# 120914  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# 0                                     Avidagos      87   15.0           Douro
# 1                                          NaN      87   14.0          Oregon
# 2                         Reserve Late Harvest      87   13.0        Michigan
# 3           Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                                 Ars In Vitro      87   15.0  Northern Spain
# ...                                        ...     ...    ...             ...
# 120910  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0           Mosel
# 120911                                     NaN      90   75.0          Oregon
# 120912                                   Kritt      90   30.0          Alsace
# 120913                                     NaN      90   32.0          Alsace
# 120914           Lieu-dit Harth Cuvée Caroline      90   21.0          Alsace
#
#                    region_1           region_2         taster_name  \
# 0                       NaN                NaN          Roger Voss
# 1         Willamette Valley  Willamette Valley        Paul Gregutt
# 2       Lake Michigan Shore                NaN  Alexander Peartree
# 3         Willamette Valley  Willamette Valley        Paul Gregutt
# 4                   Navarra                NaN   Michael Schachner
# ...                     ...                ...                 ...
# 120910                  NaN                NaN  Anna Lee C. Iijima
# 120911               Oregon       Oregon Other        Paul Gregutt
# 120912               Alsace                NaN          Roger Voss
# 120913               Alsace                NaN          Roger Voss
# 120914               Alsace                NaN          Roger Voss
#
#        taster_twitter_handle  \
# 0                 @vossroger
# 1                @paulgwine
# 2                        NaN
# 3                @paulgwine
# 4                @wineschach
# ...                      ...
# 120910                   NaN
# 120911           @paulgwine
# 120912            @vossroger
# 120913            @vossroger
# 120914            @vossroger
#
#                                                     title             variety  \
# 0           Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 1           Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 2       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 3       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 4       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# ...                                                   ...                 ...
# 120910  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...            Riesling
# 120911                  Citation 2004 Pinot Noir (Oregon)          Pinot Noir
# 120912  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 120913      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          Pinot Gris
# 120914  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                                           winery  compound    neg    neu  \
# 0                            Quinta dos Avidagos    0.6486  0.000  0.872
# 1                                      Rainstorm   -0.1280  0.053  0.947
# 2                                     St. Julian    0.3400  0.000  0.930
# 3                                   Sweet Cheeks    0.8176  0.000  0.817
# 4                                         Tandem    0.1655  0.000  0.961
# ...                                          ...       ...    ...    ...
# 120910  Dr. H. Thanisch (Erben Müller-Burggraef)    0.7331  0.000  0.838
# 120911                                  Citation    0.5267  0.000  0.916
# 120912                           Domaine Gresser    0.1548  0.068  0.873
# 120913                      Domaine Marcel Deiss    0.5267  0.000  0.896
# 120914                          Domaine Schoffit    0.7003  0.047  0.723
#
#           pos
# 0       0.128
# 1       0.000
# 2       0.070
# 3       0.183
# 4       0.039
# ...       ...
# 120910  0.162
# 120911  0.084
# 120912  0.059
# 120913  0.104
# 120914  0.230
#
# [111511 rows x 17 columns]

# %% [markdown]
# # Topic modelling

# %%
from gensim import corpora
from gensim.models.ldamodel import LdaModel
from gensim.parsing.preprocessing import STOPWORDS
import pprint

# %%
texts = [[word for word in desc.lower().split() if word not in STOPWORDS and word.isalnum() and not word.lower() in ['wine', 'drink']] for desc in list(df["description"].values)]
dictionary = corpora.Dictionary(texts) #(word_id,word) pairs not word.lower() == 'slate'
corpus = [dictionary.doc2bow(text) for text in texts] #(word_id,freq) pairs by sentence

# %%
num_topics = 5 #The number of topics that should be generated
passes = 10
lda = LdaModel(corpus, id2word=dictionary, num_topics=num_topics, passes=passes)

# %%
pp = pprint.PrettyPrinter(indent=4)
#pp.pprint(lda.show_topics(num_words=10, formatted=False))
for index, topic in lda.show_topics(formatted=False, num_words= 8):
    print('Topic: {} \nWords: {}'.format(index, ', '.join([w[0] for w in topic])))
# Out:
# Topic: 0
# Words: flavors, aromas, finish, palate, berry, plum, feels, like
# Topic: 1
# Words: black, cabernet, flavors, cherry, fruit, blend, dark, red
# Topic: 2
# Words: flavors, apple, citrus, acidity, lemon, crisp, white, fresh
# Topic: 3
# Words: palate, aromas, offers, black, alongside, opens, dried, red
# Topic: 4
# Words: ripe, fruit, tannins, rich, acidity, red, black, fruits

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

lda_display = gensimvis.prepare(lda, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [76], in <cell line: 4>()
#       1 import pyLDAvis
#       2 import pyLDAvis.gensim_models as gensimvis
# ----> 4 lda_display = gensimvis.prepare(lda, corpus, dictionary)
#       5 pyLDAvis.display(lda_display)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyLDAvis/gensim_models.py:122, in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#      77 def prepare(topic_model, corpus, dictionary, doc_topic_dist=None, **kwargs):
#      78     """Transforms the Gensim TopicModel and related corpus and dictionary into
#      79     the data structures needed for the visualization.
#      80
#    (...)
#     120     See `pyLDAvis.prepare` for **kwargs.
#     121     """
# --> 122     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
#     123     return pyLDAvis.prepare(**opts)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyLDAvis/gensim_models.py:49, in _extract_data(topic_model, corpus, dictionary, doc_topic_dists)
#      47         gamma = topic_model.inference(corpus)
#      48     else:
# ---> 49         gamma, _ = topic_model.inference(corpus)
#      50     doc_topic_dists = gamma / gamma.sum(axis=1)[:, None]
#      51 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gensim/models/ldamodel.py:721, in LdaModel.inference(self, chunk, collect_sstats)
#     719 Elogthetad = dirichlet_expectation(gammad)
#     720 expElogthetad = np.exp(Elogthetad)
# --> 721 phinorm = np.dot(expElogthetad, expElogbetad) + epsilon
#     722 # If gamma hasn't changed much, we're done.
#     723 meanchange = mean_absolute_difference(gammad, lastgamma)
#
# KeyboardInterrupt:

# %% [markdown]
# # Clustering with NLP and kMeans

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from nltk.tokenize import RegexpTokenizer
from nltk.stem.snowball import SnowballStemmer

# %%
variety_df = df.groupby('variety').filter(lambda x: len(x) > 2000)
print(variety_df['variety'].unique())
varieties = variety_df['variety'].value_counts().index.tolist()
fig, ax = plt.subplots(figsize = (25, 10))
sns.countplot(x = variety_df['variety'], order = varieties, ax = ax)
plt.xticks(rotation = 90)
plt.show()
# Out:
# ['Portuguese Red' 'Riesling' 'Pinot Noir' 'Cabernet Sauvignon'
#  'Chardonnay' 'Malbec' 'Red Blend' 'Merlot' 'Sauvignon Blanc' 'Sangiovese'
#  'Bordeaux-style Red Blend' 'Rosé' 'Zinfandel' 'Syrah' 'Nebbiolo']

# %%
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'[a-zA-Z\']+')

def tokenize(text):
    return [stemmer.stem(word) for word in tokenizer.tokenize(text.lower())]

punc = ['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}',"%"]
stop_words = text.ENGLISH_STOP_WORDS.union(punc)
desc = variety_df['description'].values
vectorizer = TfidfVectorizer(stop_words = stop_words, tokenizer = tokenize, max_features = 1000)
X = vectorizer.fit_transform(desc)
words = vectorizer.get_feature_names_out()
# Out:
# /Users/afnan/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:404: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   warnings.warn(

# %%
kmeans = KMeans(n_clusters = len(variety_df['variety'].unique()))
kmeans.fit(X)
# Out:
# KMeans(n_clusters=15)

# %%
common_words = kmeans.cluster_centers_.argsort()[:,-1:-11:-1]
for num, centroid in enumerate(common_words):
    print(str(num) + ' : ' + ', '.join(words[word] for word in centroid))
# Out:
# 0 : black, cherri, pepper, palat, fruit, dark, plum, nose, flavor, aroma
# 1 : barrel, oak, new, french, fruit, age, flavor, wine, month, spice
# 2 : cabernet, sauvignon, merlot, blend, franc, petit, verdot, black, malbec, syrah
# 3 : wine, fruit, flavor, cherri, finish, red, aroma, light, raspberri, palat
# 4 : wood, age, wine, fruit, drink, rich, ripe, tannin, structur, acid
# 5 : pinot, noir, cherri, raspberri, silki, cola, flavor, acid, drink, dri
# 6 : bodi, medium, wine, flavor, textur, finish, aroma, cherri, light, fruit
# 7 : wine, fruit, structur, tannin, age, drink, rich, firm, ripe, acid
# 8 : lemon, lime, riesl, peach, finish, palat, grapefruit, flavor, citrus, dri
# 9 : blackberri, flavor, currant, cherri, sweet, dri, tannin, soft, rich, wine
# 10 : chardonnay, pineappl, butter, flavor, toast, vanilla, tropic, oak, acid, sweet
# 11 : appl, pear, flavor, green, lemon, finish, palat, fresh, wine, acid
# 12 : palat, alongsid, tannin, aroma, cherri, black, offer, berri, spice, red
# 13 : berri, aroma, finish, herbal, plum, flavor, feel, palat, note, fruit
# 14 : wine, fruiti, drink, acid, readi, crisp, fruit, attract, soft, red

# %%
variety_df['cluster'] = kmeans.labels_
clusters = variety_df.groupby(['cluster', 'variety']).size()
fig2, ax2 = plt.subplots(figsize = (30, 15))
sns.heatmap(clusters.unstack(level = 'variety'), ax = ax2, cmap = 'Reds')

ax2.set_xlabel('variety', fontdict = {'weight': 'bold', 'size': 24})
ax2.set_ylabel('cluster', fontdict = {'weight': 'bold', 'size': 24})
for label in ax2.get_xticklabels():
    label.set_size(16)
    label.set_weight("bold")
for label in ax2.get_yticklabels():
    label.set_size(16)
    label.set_weight("bold")

# %% [markdown]
# # Recommendation system

# %%
from sklearn.neighbors import NearestNeighbors # KNN Clustering 
from scipy.sparse import csr_matrix # Compressed Sparse Row matrix
from sklearn.decomposition import TruncatedSVD # Dimensional Reduction

# %%
col = ['province','variety','points']

wine1 = df[col]
wine1 = wine1.dropna(axis=0)
wine1 = wine1.drop_duplicates(['province','variety'])
wine1 = wine1[wine1['points'] > 85]

wine_pivot = wine1.pivot(index= 'variety',columns='province',values='points').fillna(0)
wine_pivot_matrix = csr_matrix(wine_pivot)

# %%
knn = NearestNeighbors(n_neighbors=10, algorithm='brute', metric='cosine')
model_knn = knn.fit(wine_pivot_matrix)

# %%
for n in range(3):
    query_index = np.random.choice(wine_pivot.shape[0])
    #print(n, query_index)
    distance, indice = model_knn.kneighbors(wine_pivot.iloc[query_index,:].values.reshape(1,-1), n_neighbors=6)
    for i in range(0, len(distance.flatten())):
        if  i == 0:
            print('Recommendation for ## {0} ##:'.format(wine_pivot.index[query_index]))
        else:
            print('{0}: {1} with distance: {2}'.format(i,wine_pivot.index[indice.flatten()[i]],distance.flatten()[i]))
    print('\n')
# Out:
# Recommendation for ## Passerina ##:
# 1: Cesanese d'Affile with distance: 0.0
# 2: Lambrusco di Sorbara with distance: 0.0
# 3: Cesanese with distance: 0.0
# 4: Passerina with distance: 0.0
# 5: Lambrusco Salamino with distance: 0.0
#
#
# Recommendation for ## Tokay ##:
# 1: Muscadelle with distance: 0.3920544062907231
# 2: Shiraz-Malbec with distance: 0.4099168498640393
# 3: Marsanne with distance: 0.4890623259466864
# 4: Shiraz-Viognier with distance: 0.5030659996260876
# 5: Cabernet Sauvignon-Sangiovese with distance: 0.5070859462092459
#
#
# Recommendation for ## Moscatel ##:
# 1: Rabigato with distance: 0.6659018867786529
# 2: Portuguese Rosé with distance: 0.6659018867786529
# 3: Tinta Francisca with distance: 0.6659018867786529
# 4: Sousão with distance: 0.6659018867786529
# 5: Códega do Larinho with distance: 0.6659018867786529
